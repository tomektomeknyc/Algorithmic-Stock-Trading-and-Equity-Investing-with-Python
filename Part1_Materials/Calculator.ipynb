# %% [markdown]
# # Calculator

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Multiplication

# %% [markdown]
# Please read :https://en.wikipedia.org/wiki/Addition

# %%
3*2
# Out:
# 6

# %% [markdown]
# ## Addition

# %%
5+2
# Out:
# 7
